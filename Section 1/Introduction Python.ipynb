# %%
print("Hello, World!")

# %%
# تعريف متغير نصي
name = "Ahmed"

# تعريف متغير رقمي
age = 25

# طباعة المتغيرات
print(name)  # يطبع: Ahmed
print(age)   # يطبع: 25

# تغيير قيمة المتغير
age = age + 1
print(age)   # يطبع: 26
# Out:
# Ahmed
# 25
# 26

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
sum = num1 + num2
print("Sum:", sum)

# %%
# نوع نصي (String)
text = "Hello, Python!"
print(type(text))  # يطبع: <class 'str'>

# نوع رقمي صحيح (Integer)
number = 10
print(type(number))  # يطبع: <class 'int'>

# نوع رقمي عائم (Float)
decimal = 3.14
print(type(decimal))  # يطبع: <class 'float'>

# نوع منطقي (Boolean)
is_true = True
print(type(is_true))  # يطبع: <class 'bool'>

# نوع قائمة (List)
my_list = [1, 2, 3, "apple"]
print(type(my_list))  # يطبع: <class 'list'>
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'list'>

# %%
#if condition:
    # code to run if condition is True
#elif condition:  # optional
    # code to run if previous condition is False and this one is True
#else:  # optional
    # code to run if all conditions are False

# %%
number = int(input("Enter a number: "))
if number > 0:
    print("Number is positive")
else:
    print("Number is not positive")

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(num, "is even")
else:
    print(num, "is odd")

# %%
# مثال مع elif
score = 75
if score >= 90:
    print("Excellent")
elif score >= 70:
    print("Good")  # يطبع: Good
else:
    print("Needs improvement")
# Out:
# Good

# %%
num1 = float(input("Enter first number: "))
op = input("Enter operation (+, -, *, /): ")
num2 = float(input("Enter second number: "))

if op == '+':
    print(num1 + num2)
elif op == '-':
    print(num1 - num2)
elif op == '*':
    print(num1 * num2)
elif op == '/':
    print("Error: Division by zero!" if num2 == 0 else num1 / num2)
else:
    print("Invalid operation!")

# %%
#for variable in iterable:
    # code to repeat for each item in iterable

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# تكرار على قائمة
fruits = ["apple", "banana", "orange"]
for fruit in fruits:
    print(fruit)  # يطبع كل فاكهة في سطر منفصل

# تكرار على نطاق أرقام
for i in range(5):  # من 0 إلى 4
    print(i)  # يطبع: 0 1 2 3 4
# Out:
# apple
# banana
# orange
# 0
# 1
# 2
# 3
# 4

# %%
fruits = ["apple", "banana", "orange"]
for fruit in fruits:
    print("I like", fruit)

# %%
#while condition:
    # code to repeat as long as condition is True

# %%
count = 0
while count < 5:
    print(count)  # يطبع: 0 1 2 3 4
    count = count + 1  # زيادة العداد لتجنب حلقة لا نهائية
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
count = 1
sum = 0
while count <= 5:
    sum += count
    count += 1
print("Sum of 1 to 5 is:", sum)

# %%
password = ""
while password != "Basant":
    password = input("Enter the password: ")
print("Welcome!")
# Out:
# Enter the password: Basant
# Welcome!

# %%
day = input("Enter a day (1-7): ")
match day:
    case "1":
        print("Monday")
    case "2":
        print("Tuesday")
    case _:
        print("Invalid or other day")

# %%
color = input("Enter a color (red, blue, green): ")

# خطوة 2: بنقارن اللون بـ match
match color:
    case "red":  # لو كتب red
        print("Red is like an apple!")
    case "blue":  # لو كتب blue
        print("Blue is like the sky!")
    case "green":  # لو كتب green
        print("Green is like grass!")
    case _:  # لو كتب حاجة تانية
        print("I don't know that color!")

# %%
#def function_name(parameters):
    # code to execute
 #   return value  # optional

# %%
def say_hi():
    print("Hi!")

say_hi()
# Out:
# Hi!

# %%
def square(num):
    return num * num

number = float(input("Enter a number: "))
result = square(number)
print("Square of", number, "is", result)
# Out:
# Enter a number: 2
# Square of 2.0 is 4.0

# %%
def print_name(name):
    print("Your name is:", name)

name = input("Enter your name: ")
print_name(name)

# %%
print ("/____|" )
print ("    /|" )
print ("   / |" )
print ("  /  |" )
print (" /   |" )
#شكل المثلث بتاعي باظ لانه بينفذ بس مش فاهم اني عاوز اطبع مثلث

# %%
#variable (المتغيرعبارةعن صندوق صغيرانابشيل جواه حاجة)
#important------> بتسهل علي المبرمج
print("there was a boy called ahmed ")
print("he was 32 years old")
print("he liked his name ahmed ")
print("but wasn't happy about being 32")

# %%
#stringاي كلام هيبقي متخزن ك نص او حرف  هيبقي متخزن جواه
print("basant Shaker")
print("rana\nElsay\ned")#\n new line
print("basant\" ")
print("basant""Shaker")
print("mohammed\vv")
print("bbbbb\tbbbb")#\t 6 tab
# Out:
# basant Shaker
# rana
# Elsay
# ed
# basant"
# basantShaker
# mohammedv
# bbbbb	bbbb

# %%
x="Basant"
print(x+" hello world"+" thank you")
print(x.lower())
print(x.upper())
print(x.islower())#check كل الجملة بتاعي small litter
print(x.isupper())#العكس
print(x.lower().islower())
print(x.upper().isupper())

# %%
x="Basant"
print(len(x))#بتعد من 1 وليس صفر
print(len("cat"))
print(x[1])
print(x[0])
# Out:
# 6
# 3
# a
# B

# %%
frist_name="Ahmed"
last_name="Elmetwally"
print(frist_name[0],last_name[0])#هنا بنطلع الحرف بواسطة ال index
print(last_name.index("m"))#هنا هنطلع ال index بتاع الحرف
#print(last_name.index("x"))#substring not found
print(last_name.index("Elmetwally"))#print 0 لان هو هيبص فقط علي اول حرف من الجملة بتاعي
print(last_name.replace("Elme","k"))
# Out:
# A E
# 2
# 0
# ktwally
